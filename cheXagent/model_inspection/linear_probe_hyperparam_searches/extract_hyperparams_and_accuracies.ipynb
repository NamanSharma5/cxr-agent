# %%
from pathlib import Path

# %%
def parse_log_file(log_file_path):
    # Initial setup
    best_results = []
    current_hyperparameters = None
    best_accuracy = 0.0
    with open(log_file_path, 'r') as file:
        for line in file:
            # Strip any leading/trailing whitespaces
            line = line.strip()
            
            # Find hyperparameter configuration block
            if line.startswith('Hyperparameters:'):
                # Store best accuracy so far (except at the very beginning)
                if current_hyperparameters:
                    best_results.append((current_hyperparameters, best_accuracy))
                
                # New block of hyperparameters, reset tracking variables
                current_hyperparameters = line
                best_accuracy = 0.0
            elif line.startswith('Epoch'):
                # Process each epoch line within a hyperparameter block
                parts = line.split(',')
                # Example Val Accuracy part: ' Val Accuracy: 0.1333705373108387'
                val_accuracy_text = parts[-1].strip()
                accuracy = float(val_accuracy_text.split(' ')[-1])
                
                # Track the best accuracy
                best_accuracy = max(best_accuracy, accuracy)
        
        # Append the last block's results
        if current_hyperparameters:
            best_results.append((current_hyperparameters, best_accuracy))
    
    return best_results

# %%
# Call the function
log_file_path = '/vol/biomedic3/bglocker/ugproj2324/nns20/CheXagent/model_inspection/linear_probe_hyperparam_searches/VinDr_search'
results = parse_log_file(log_file_path)
for result in results:
    print(result)
# Out:
# ('Hyperparameters: layer=post_layer_norm, batch_size=64, num_epochs=10, learning_rate=0.0001', 0.6920454621315002)
# ('Hyperparameters: layer=post_layer_norm, batch_size=64, num_epochs=10, learning_rate=0.001', 0.7113636374473572)
# ('Hyperparameters: layer=post_layer_norm, batch_size=64, num_epochs=10, learning_rate=0.01', 0.6923295497894287)
# ('Hyperparameters: layer=post_layer_norm, batch_size=64, num_epochs=20, learning_rate=0.0001', 0.693181824684143)
# ('Hyperparameters: layer=post_layer_norm, batch_size=64, num_epochs=20, learning_rate=0.001', 0.7122159123420715)
# ('Hyperparameters: layer=post_layer_norm, batch_size=64, num_epochs=20, learning_rate=0.01', 0.6892045497894287)
# ('Hyperparameters: layer=post_layer_norm, batch_size=64, num_epochs=40, learning_rate=0.0001', 0.7122159123420715)
# ('Hyperparameters: layer=post_layer_norm, batch_size=64, num_epochs=40, learning_rate=0.001', 0.7230113744735718)
# ('Hyperparameters: layer=post_layer_norm, batch_size=64, num_epochs=40, learning_rate=0.01', 0.696875)
# ('Hyperparameters: layer=post_layer_norm, batch_size=128, num_epochs=10, learning_rate=0.0001', 0.7104640205701193)
# ('Hyperparameters: layer=post_layer_norm, batch_size=128, num_epochs=10, learning_rate=0.001', 0.7161458333333334)
# ('Hyperparameters: layer=post_layer_norm, batch_size=128, num_epochs=10, learning_rate=0.01', 0.7260890205701193)
# ('Hyperparameters: layer=post_layer_norm, batch_size=128, num_epochs=20, learning_rate=0.0001', 0.6979166666666666)
# ('Hyperparameters: layer=post_layer_norm, batch_size=128, num_epochs=20, learning_rate=0.001', 0.7286931872367859)
# ('Hyperparameters: layer=post_layer_norm, batch_size=128, num_epochs=20, learning_rate=0.01', 0.7080966035525004)
# ('Hyperparameters: layer=post_layer_norm, batch_size=128, num_epochs=40, learning_rate=0.0001', 0.7201704581578573)
# ('Hyperparameters: layer=post_layer_norm, batch_size=128, num_epochs=40, learning_rate=0.001', 0.7286931872367859)
# ('Hyperparameters: layer=post_layer_norm, batch_size=128, num_epochs=40, learning_rate=0.01', 0.7159091035525004)
# ('Hyperparameters: layer=post_layer_norm, batch_size=256, num_epochs=10, learning_rate=0.0001', 0.7183949053287506)
# ('Hyperparameters: layer=post_layer_norm, batch_size=256, num_epochs=10, learning_rate=0.001', 0.6995738744735718)
# ('Hyperparameters: layer=post_layer_norm, batch_size=256, num_epochs=10, learning_rate=0.01', 0.7638494372367859)
# ('Hyperparameters: layer=post_layer_norm, batch_size=256, num_epochs=20, learning_rate=0.0001', 0.712890625)
# ('Hyperparameters: layer=post_layer_norm, batch_size=256, num_epochs=20, learning_rate=0.001', 0.7602983117103577)
# ('Hyperparameters: layer=post_layer_norm, batch_size=256, num_epochs=20, learning_rate=0.01', 0.7716619372367859)
# ('Hyperparameters: layer=post_layer_norm, batch_size=256, num_epochs=40, learning_rate=0.0001', 0.7262074053287506)
# ('Hyperparameters: layer=post_layer_norm, batch_size=256, num_epochs=40, learning_rate=0.001', 0.7508878111839294)
# ('Hyperparameters: layer=post_layer_norm, batch_size=256, num_epochs=40, learning_rate=0.01', 0.7469815611839294)
# ('Hyperparameters: layer=post_layer_norm, batch_size=512, num_epochs=10, learning_rate=0.0001', 0.6833333373069763)
# ('Hyperparameters: layer=post_layer_norm, batch_size=512, num_epochs=10, learning_rate=0.001', 0.6899999976158142)
# ('Hyperparameters: layer=post_layer_norm, batch_size=512, num_epochs=10, learning_rate=0.01', 0.6966666579246521)
# ('Hyperparameters: layer=post_layer_norm, batch_size=512, num_epochs=20, learning_rate=0.0001', 0.6833333373069763)
# ('Hyperparameters: layer=post_layer_norm, batch_size=512, num_epochs=20, learning_rate=0.001', 0.7100000381469727)
# ('Hyperparameters: layer=post_layer_norm, batch_size=512, num_epochs=20, learning_rate=0.01', 0.7133333683013916)
# ('Hyperparameters: layer=post_layer_norm, batch_size=512, num_epochs=40, learning_rate=0.0001', 0.6899999976158142)
# ('Hyperparameters: layer=post_layer_norm, batch_size=512, num_epochs=40, learning_rate=0.001', 0.7133333683013916)
# ('Hyperparameters: layer=post_layer_norm, batch_size=512, num_epochs=40, learning_rate=0.01', 0.7133333683013916)
# ('Hyperparameters: layer=post_layer_norm, batch_size=1024, num_epochs=10, learning_rate=0.0001', 0.643333375453949)
# ('Hyperparameters: layer=post_layer_norm, batch_size=1024, num_epochs=10, learning_rate=0.001', 0.6866666674613953)
# ('Hyperparameters: layer=post_layer_norm, batch_size=1024, num_epochs=10, learning_rate=0.01', 0.6866666674613953)
# ('Hyperparameters: layer=post_layer_norm, batch_size=1024, num_epochs=20, learning_rate=0.0001', 0.6866666674613953)
# ('Hyperparameters: layer=post_layer_norm, batch_size=1024, num_epochs=20, learning_rate=0.001', 0.7033333778381348)
# ('Hyperparameters: layer=post_layer_norm, batch_size=1024, num_epochs=20, learning_rate=0.01', 0.6899999976158142)
# ('Hyperparameters: layer=post_layer_norm, batch_size=1024, num_epochs=40, learning_rate=0.0001', 0.6866666674613953)
# ('Hyperparameters: layer=post_layer_norm, batch_size=1024, num_epochs=40, learning_rate=0.001', 0.6966666579246521)
# ('Hyperparameters: layer=post_layer_norm, batch_size=1024, num_epochs=40, learning_rate=0.01', 0.7100000381469727)
# ('Hyperparameters: layer=post_layer_norm, batch_size=3000, num_epochs=10, learning_rate=0.0001', 0.0833333358168602)
# ('Hyperparameters: layer=post_layer_norm, batch_size=3000, num_epochs=10, learning_rate=0.001', 0.6866666674613953)
# ('Hyperparameters: layer=post_layer_norm, batch_size=3000, num_epochs=10, learning_rate=0.01', 0.6866666674613953)
# ('Hyperparameters: layer=post_layer_norm, batch_size=3000, num_epochs=20, learning_rate=0.0001', 0.6399999856948853)
# ('Hyperparameters: layer=post_layer_norm, batch_size=3000, num_epochs=20, learning_rate=0.001', 0.6866666674613953)
# ('Hyperparameters: layer=post_layer_norm, batch_size=3000, num_epochs=20, learning_rate=0.01', 0.699999988079071)
# ('Hyperparameters: layer=post_layer_norm, batch_size=3000, num_epochs=40, learning_rate=0.0001', 0.6866666674613953)
# ('Hyperparameters: layer=post_layer_norm, batch_size=3000, num_epochs=40, learning_rate=0.001', 0.6966666579246521)
# ('Hyperparameters: layer=post_layer_norm, batch_size=3000, num_epochs=40, learning_rate=0.01', 0.7100000381469727)
# ('Hyperparameters: layer=q_former, batch_size=64, num_epochs=10, learning_rate=0.0001', 0.7048295497894287)
# ('Hyperparameters: layer=q_former, batch_size=64, num_epochs=10, learning_rate=0.001', 0.6821022748947143)
# ('Hyperparameters: layer=q_former, batch_size=64, num_epochs=10, learning_rate=0.01', 0.7136363744735718)
# ('Hyperparameters: layer=q_former, batch_size=64, num_epochs=20, learning_rate=0.0001', 0.7110795497894287)
# ('Hyperparameters: layer=q_former, batch_size=64, num_epochs=20, learning_rate=0.001', 0.6826704621315003)
# ('Hyperparameters: layer=q_former, batch_size=64, num_epochs=20, learning_rate=0.01', 0.6977272748947143)
# ('Hyperparameters: layer=q_former, batch_size=64, num_epochs=40, learning_rate=0.0001', 0.7017045497894288)
# ('Hyperparameters: layer=q_former, batch_size=64, num_epochs=40, learning_rate=0.001', 0.6798295497894287)
# ('Hyperparameters: layer=q_former, batch_size=64, num_epochs=40, learning_rate=0.01', 0.6892045497894287)
# ('Hyperparameters: layer=q_former, batch_size=128, num_epochs=10, learning_rate=0.0001', 0.7140151659647623)
# ('Hyperparameters: layer=q_former, batch_size=128, num_epochs=10, learning_rate=0.001', 0.6751893957455953)
# ('Hyperparameters: layer=q_former, batch_size=128, num_epochs=10, learning_rate=0.01', 0.7026515205701193)
# ('Hyperparameters: layer=q_former, batch_size=128, num_epochs=20, learning_rate=0.0001', 0.7180397907892863)
# ('Hyperparameters: layer=q_former, batch_size=128, num_epochs=20, learning_rate=0.001', 0.7033617496490479)
# ('Hyperparameters: layer=q_former, batch_size=128, num_epochs=20, learning_rate=0.01', 0.7026515205701193)
# ('Hyperparameters: layer=q_former, batch_size=128, num_epochs=40, learning_rate=0.0001', 0.7386363744735718)
# ('Hyperparameters: layer=q_former, batch_size=128, num_epochs=40, learning_rate=0.001', 0.7026515205701193)
# ('Hyperparameters: layer=q_former, batch_size=128, num_epochs=40, learning_rate=0.01', 0.6801609992980957)
# ('Hyperparameters: layer=q_former, batch_size=256, num_epochs=10, learning_rate=0.0001', 0.7297585308551788)
# ('Hyperparameters: layer=q_former, batch_size=256, num_epochs=10, learning_rate=0.001', 0.7144886553287506)
# ('Hyperparameters: layer=q_former, batch_size=256, num_epochs=10, learning_rate=0.01', 0.7235440611839294)
# ('Hyperparameters: layer=q_former, batch_size=256, num_epochs=20, learning_rate=0.0001', 0.7434304058551788)
# ('Hyperparameters: layer=q_former, batch_size=256, num_epochs=20, learning_rate=0.001', 0.7411221861839294)
# ('Hyperparameters: layer=q_former, batch_size=256, num_epochs=20, learning_rate=0.01', 0.7238991558551788)
# ('Hyperparameters: layer=q_former, batch_size=256, num_epochs=40, learning_rate=0.0001', 0.7567471861839294)
# ('Hyperparameters: layer=q_former, batch_size=256, num_epochs=40, learning_rate=0.001', 0.7223011553287506)
# ('Hyperparameters: layer=q_former, batch_size=256, num_epochs=40, learning_rate=0.01', 0.7254971861839294)
# ('Hyperparameters: layer=q_former, batch_size=512, num_epochs=10, learning_rate=0.0001', 0.7133333683013916)
# ('Hyperparameters: layer=q_former, batch_size=512, num_epochs=10, learning_rate=0.001', 0.6833333373069763)
# ('Hyperparameters: layer=q_former, batch_size=512, num_epochs=10, learning_rate=0.01', 0.6933333277702332)
# ('Hyperparameters: layer=q_former, batch_size=512, num_epochs=20, learning_rate=0.0001', 0.7166666984558105)
# ('Hyperparameters: layer=q_former, batch_size=512, num_epochs=20, learning_rate=0.001', 0.6866666674613953)
# ('Hyperparameters: layer=q_former, batch_size=512, num_epochs=20, learning_rate=0.01', 0.6899999976158142)
# ('Hyperparameters: layer=q_former, batch_size=512, num_epochs=40, learning_rate=0.0001', 0.7166666984558105)
# ('Hyperparameters: layer=q_former, batch_size=512, num_epochs=40, learning_rate=0.001', 0.6899999976158142)
# ('Hyperparameters: layer=q_former, batch_size=512, num_epochs=40, learning_rate=0.01', 0.699999988079071)
# ('Hyperparameters: layer=q_former, batch_size=1024, num_epochs=10, learning_rate=0.0001', 0.6933333277702332)
# ('Hyperparameters: layer=q_former, batch_size=1024, num_epochs=10, learning_rate=0.001', 0.699999988079071)
# ('Hyperparameters: layer=q_former, batch_size=1024, num_epochs=10, learning_rate=0.01', 0.6833333373069763)
# ('Hyperparameters: layer=q_former, batch_size=1024, num_epochs=20, learning_rate=0.0001', 0.7133333683013916)
# ('Hyperparameters: layer=q_former, batch_size=1024, num_epochs=20, learning_rate=0.001', 0.6899999976158142)
# ('Hyperparameters: layer=q_former, batch_size=1024, num_epochs=20, learning_rate=0.01', 0.7033333778381348)
# ('Hyperparameters: layer=q_former, batch_size=1024, num_epochs=40, learning_rate=0.0001', 0.7133333683013916)
# ('Hyperparameters: layer=q_former, batch_size=1024, num_epochs=40, learning_rate=0.001', 0.6899999976158142)
# ('Hyperparameters: layer=q_former, batch_size=1024, num_epochs=40, learning_rate=0.01', 0.6966666579246521)
# ('Hyperparameters: layer=q_former, batch_size=3000, num_epochs=10, learning_rate=0.0001', 0.6866666674613953)
# ('Hyperparameters: layer=q_former, batch_size=3000, num_epochs=10, learning_rate=0.001', 0.6866666674613953)
# ('Hyperparameters: layer=q_former, batch_size=3000, num_epochs=10, learning_rate=0.01', 0.6866666674613953)
# ('Hyperparameters: layer=q_former, batch_size=3000, num_epochs=20, learning_rate=0.0001', 0.699999988079071)
# ('Hyperparameters: layer=q_former, batch_size=3000, num_epochs=20, learning_rate=0.001', 0.6966666579246521)
# ('Hyperparameters: layer=q_former, batch_size=3000, num_epochs=20, learning_rate=0.01', 0.6866666674613953)
# ('Hyperparameters: layer=q_former, batch_size=3000, num_epochs=40, learning_rate=0.0001', 0.7033333778381348)
# ('Hyperparameters: layer=q_former, batch_size=3000, num_epochs=40, learning_rate=0.001', 0.6933333277702332)
# ('Hyperparameters: layer=q_former, batch_size=3000, num_epochs=40, learning_rate=0.01', 0.6933333277702332)

# %%
# write the results to a csv
output_file_path = Path(log_file_path).with_suffix('.csv')
header = ["layer","batch_size","num_epochs","learning_rate","val_accuracy"]
with open(output_file_path, 'w') as file:
    for result in results:
        # split hyperparameters into separate columns
        hyperparameters = [val.split("=")[1] for val  in result[0].split(',')]
        # write each hyperparameter and the accuracy to the csv
        file.write(",".join(hyperparameters + [str(result[1])]) + "\n")
